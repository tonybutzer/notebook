# %% [markdown]
# # References
# - https://kontext.tech/column/code-snippets/402/pandas-dataframe-plot-pie-chart
# - https://medium.com/dunder-data/selecting-subsets-of-data-in-pandas-6fcd0170be9c
# - https://data36.com/pandas-tutorial-2-aggregation-and-grouping/

# %%
import pandas as pd

# %%
df = pd.read_csv("abc.csv")

# %%
df
# Out:
#      lastname                firstname                            boss  \
# 0     Anthony  Michelle (Contractor) L    Calli (Contractor) Jenkerson
# 1       Ballu     Anudeep (Contractor)                             NaN
# 2    Benedict                Trenton D                             NaN
# 3       Boyte                  Stephen                   Kristi Sayler
# 4       Bunde       Brett (Contractor)       Danny (Contractor) Howard
# 5      Butzer        Tony (Contractor)   Cory (Contractor) Van Batavia
# 6       Dahal    Devendra (Contractor)       Danny (Contractor) Howard
# 7   Danielson     Patrick (Contractor)       Danny (Contractor) Howard
# 8       Holen    Cheryl (Contractor) L                             NaN
# 9     Mainali       Pukar (Contractor)                             NaN
# 10   Mcelhone                Maxwell T                             NaN
# 11     Oimoen   Michael (Contractor) J                             NaN
# 12    Pastick      Neal (Contractor) J       Danny (Contractor) Howard
# 13     Postma        Kory (Contractor)      Jayson (Contractor) Holter
# 14      Rigge                Matthew B                   Kristi Sayler
# 15      Rover                 Jennifer                  Peter Doucette
# 16     Schoen       Candi (Contractor)                             NaN
# 17   Shrestha                   Dinesh                             NaN
# 18      Smith     Kelcy (Contractor) L         Ryan (Contractor) Reker
# 19        Sun                  Minxuan                             NaN
# 20      Wylie                  Bruce K                   Kristi Sayler
# 21      Young     Claudia (Contractor)                             NaN
# 22       Zhou       Qiang (Contractor)       Ramesh (Contractor) Singh
#
#                                      division
# 0                            Science Division
# 1                                         NaN
# 2                                         NaN
# 3    Integrated Science & Applications Branch
# 4                            Science Division
# 5            Satellite Ground System Division
# 6                            Science Division
# 7                            Science Division
# 8                                         NaN
# 9                                         NaN
# 10                                        NaN
# 11                                        NaN
# 12                           Science Division
# 13           Satellite Ground System Division
# 14   Integrated Science & Applications Branch
# 15   Integrated Science & Applications Branch
# 16                                        NaN
# 17                                        NaN
# 18                           Science Division
# 19                                        NaN
# 20   Integrated Science & Applications Branch
# 21                                        NaN
# 22                           Science Division

# %%
import numpy as np
df1 = df.replace(np.nan, '', regex=True)

# %%
df1
# Out:
#      lastname                firstname                            boss  \
# 0     Anthony  Michelle (Contractor) L    Calli (Contractor) Jenkerson
# 1       Ballu     Anudeep (Contractor)
# 2    Benedict                Trenton D
# 3       Boyte                  Stephen                   Kristi Sayler
# 4       Bunde       Brett (Contractor)       Danny (Contractor) Howard
# 5      Butzer        Tony (Contractor)   Cory (Contractor) Van Batavia
# 6       Dahal    Devendra (Contractor)       Danny (Contractor) Howard
# 7   Danielson     Patrick (Contractor)       Danny (Contractor) Howard
# 8       Holen    Cheryl (Contractor) L
# 9     Mainali       Pukar (Contractor)
# 10   Mcelhone                Maxwell T
# 11     Oimoen   Michael (Contractor) J
# 12    Pastick      Neal (Contractor) J       Danny (Contractor) Howard
# 13     Postma        Kory (Contractor)      Jayson (Contractor) Holter
# 14      Rigge                Matthew B                   Kristi Sayler
# 15      Rover                 Jennifer                  Peter Doucette
# 16     Schoen       Candi (Contractor)
# 17   Shrestha                   Dinesh
# 18      Smith     Kelcy (Contractor) L         Ryan (Contractor) Reker
# 19        Sun                  Minxuan
# 20      Wylie                  Bruce K                   Kristi Sayler
# 21      Young     Claudia (Contractor)
# 22       Zhou       Qiang (Contractor)       Ramesh (Contractor) Singh
#
#                                      division
# 0                            Science Division
# 1
# 2
# 3    Integrated Science & Applications Branch
# 4                            Science Division
# 5            Satellite Ground System Division
# 6                            Science Division
# 7                            Science Division
# 8
# 9
# 10
# 11
# 12                           Science Division
# 13           Satellite Ground System Division
# 14   Integrated Science & Applications Branch
# 15   Integrated Science & Applications Branch
# 16
# 17
# 18                           Science Division
# 19
# 20   Integrated Science & Applications Branch
# 21
# 22                           Science Division

# %%
for index,row in df1.iterrows():
    if row.boss:
        print(row.boss)
    else:
        print('NULL',row.boss)
        df1.loc[index,'boss'] = 'Calli (Contractor) Jenkerson'
# Out:
#  Calli (Contractor) Jenkerson
# NULL
# NULL
#  Kristi Sayler
#  Danny (Contractor) Howard
#  Cory (Contractor) Van Batavia
#  Danny (Contractor) Howard
#  Danny (Contractor) Howard
# NULL
# NULL
# NULL
# NULL
#  Danny (Contractor) Howard
#  Jayson (Contractor) Holter
#  Kristi Sayler
#  Peter Doucette
# NULL
# NULL
#  Ryan (Contractor) Reker
# NULL
#  Kristi Sayler
# NULL
#  Ramesh (Contractor) Singh

# %%
df1.to_csv('abc.csv',index=False)

# %%
# !ls; cat abc.csv
# Out:
# 00-git-clone-download-class-notebook-materials.ipynb
# 01-Students.ipynb
# 01-notebook-basic-navigation.ipynb
# 02-markdown.ipynb
# 02a-creating-a-new-notebook.ipynb
# 03-zen.ipynb
# 04-students-redirector.ipynb
# 05-Ten-Things.ipynb
# 99-Students-Copy1.ipynb
# abc.csv
# studentsV1.csv
# studentsV2.csv
# lastname,firstname,boss,division
# Anthony,Michelle (Contractor) L, Calli (Contractor) Jenkerson, Science Division
# Ballu,Anudeep (Contractor),Calli (Contractor) Jenkerson,Science Division
# Benedict,Trenton D,Calli (Contractor) Jenkerson,Science Division
# Boyte,Stephen, Kristi Sayler, Integrated Science & Applications Branch
# Bunde,Brett (Contractor), Danny (Contractor) Howard, Science Division
# Butzer,Tony (Contractor), Cory (Contractor) Van Batavia, Satellite Ground System Division
# Dahal,Devendra (Contractor), Danny (Contractor) Howard, Science Division
# Danielson,Patrick (Contractor), Danny (Contractor) Howard, Science Division
# Holen,Cheryl (Contractor) L,Calli (Contractor) Jenkerson,Science Division
# Mainali,Pukar (Contractor),Calli (Contractor) Jenkerson,Science Division
# Mcelhone,Maxwell T,Calli (Contractor) Jenkerson,Science Division
# Oimoen,Michael (Contractor) J,Calli (Contractor) Jenkerson,Science Division
# Pastick,Neal (Contractor) J, Danny (Contractor) Howard, Science Division
# Postma,Kory (Contractor), Jayson (Contractor) Holter, Satellite Ground System Division
# Rigge,Matthew B, Kristi Sayler, Integrated Science & Applications Branch
# Rover,Jennifer, Peter Doucette, Integrated Science & Applications Branch
# Schoen,Candi (Contractor),Calli (Contractor) Jenkerson,Science Division
# Shrestha,Dinesh,Calli (Contractor) Jenkerson,Science Division
# Smith,Kelcy (Contractor) L, Ryan (Contractor) Reker, Science Division
# Sun,Minxuan,Calli (Contractor) Jenkerson,Science Division
# Wylie,Bruce K, Kristi Sayler, Integrated Science & Applications Branch
# Young,Claudia (Contractor),Calli (Contractor) Jenkerson,Science Division
# Zhou,Qiang (Contractor), Ramesh (Contractor) Singh, Science Division

# %%
import re
for index,row in df.iterrows():
    #print(row)
    fn = re.sub(r"<.*>","", row.firstname)
    fn = fn.strip()
    print ("<%s>" % (fn))
    df.loc[index, 'firstname'] = fn
# Out:
# <Neal (Contractor) J>
# <Kory (Contractor)>
# <Brett (Contractor)>
# <Patrick (Contractor)>
# <Tony (Contractor)>
# <Devendra (Contractor)>
# <Bruce K>
# <Jennifer>
# <Qiang (Contractor)>
# <Matthew B>
# <Stephen>
# <Kelcy (Contractor) L>
# <Michelle (Contractor) L>
# <Anudeep (Contractor)>
# <Pukar (Contractor)>
# <Minxuan>
# <Maxwell T>
# <Claudia (Contractor)>
# <Cheryl (Contractor) L>
# <Neal (Contractor) J>
# <Kory (Contractor)>
# <Brett (Contractor)>
# <Patrick (Contractor)>
# <Devendra (Contractor)>
# <Bruce K>
# <Jennifer>
# <Qiang (Contractor)>
# <Matthew B>
# <Stephen>
# <Kelcy (Contractor) L>
# <Michelle (Contractor) L>
# <Trenton D>
# <Dinesh>
# <Candi (Contractor)>
# <Michael (Contractor) J>

# %%
df
# Out:
#      lastname                firstname                            boss  \
# 0     Pastick      Neal (Contractor) J       Danny (Contractor) Howard
# 1      Postma        Kory (Contractor)      Jayson (Contractor) Holter
# 2       Bunde       Brett (Contractor)       Danny (Contractor) Howard
# 3   Danielson     Patrick (Contractor)       Danny (Contractor) Howard
# 4      Butzer        Tony (Contractor)   Cory (Contractor) Van Batavia
# 5       Dahal    Devendra (Contractor)       Danny (Contractor) Howard
# 6       Wylie                  Bruce K                   Kristi Sayler
# 7       Rover                 Jennifer                  Peter Doucette
# 8        Zhou       Qiang (Contractor)       Ramesh (Contractor) Singh
# 9       Rigge                Matthew B                   Kristi Sayler
# 10      Boyte                  Stephen                   Kristi Sayler
# 11      Smith     Kelcy (Contractor) L         Ryan (Contractor) Reker
# 12    Anthony  Michelle (Contractor) L    Calli (Contractor) Jenkerson
# 13      Ballu     Anudeep (Contractor)                             NaN
# 14    Mainali       Pukar (Contractor)                             NaN
# 15        Sun                  Minxuan                             NaN
# 16   Mcelhone                Maxwell T                             NaN
# 17      Young     Claudia (Contractor)                             NaN
# 18      Holen    Cheryl (Contractor) L                             NaN
# 19    Pastick      Neal (Contractor) J                             NaN
# 20     Postma        Kory (Contractor)                             NaN
# 21      Bunde       Brett (Contractor)                             NaN
# 22  Danielson     Patrick (Contractor)                             NaN
# 23      Dahal    Devendra (Contractor)                             NaN
# 24      Wylie                  Bruce K                             NaN
# 25      Rover                 Jennifer                             NaN
# 26       Zhou       Qiang (Contractor)                             NaN
# 27      Rigge                Matthew B                             NaN
# 28      Boyte                  Stephen                             NaN
# 29      Smith     Kelcy (Contractor) L                             NaN
# 30    Anthony  Michelle (Contractor) L                             NaN
# 31   Benedict                Trenton D                             NaN
# 32   Shrestha                   Dinesh                             NaN
# 33     Schoen       Candi (Contractor)                             NaN
# 34     Oimoen   Michael (Contractor) J                             NaN
#
#                                      division
# 0                            Science Division
# 1            Satellite Ground System Division
# 2                            Science Division
# 3                            Science Division
# 4            Satellite Ground System Division
# 5                            Science Division
# 6    Integrated Science & Applications Branch
# 7    Integrated Science & Applications Branch
# 8                            Science Division
# 9    Integrated Science & Applications Branch
# 10   Integrated Science & Applications Branch
# 11                           Science Division
# 12                           Science Division
# 13                                        NaN
# 14                                        NaN
# 15                                        NaN
# 16                                        NaN
# 17                                        NaN
# 18                                        NaN
# 19                                        NaN
# 20                                        NaN
# 21                                        NaN
# 22                                        NaN
# 23                                        NaN
# 24                                        NaN
# 25                                        NaN
# 26                                        NaN
# 27                                        NaN
# 28                                        NaN
# 29                                        NaN
# 30                                        NaN
# 31                                        NaN
# 32                                        NaN
# 33                                        NaN
# 34                                        NaN

# %%
df.to_csv('abc.csv',index=False)

# %%
# !ls; cat abc.csv
# Out:
# 00-git-clone-download-class-notebook-materials.ipynb
# 01-Students.ipynb
# 01-notebook-basic-navigation.ipynb
# 02-markdown.ipynb
# 02a-creating-a-new-notebook.ipynb
# 03-zen.ipynb
# 04-students-redirector.ipynb
# 05-Ten-Things.ipynb
# 99-Students-Copy1.ipynb
# abc.csv
# studentsV1.csv
# studentsV2.csv
# lastname,firstname,boss,division
# Pastick,Neal (Contractor) J, Danny (Contractor) Howard, Science Division
# Postma,Kory (Contractor), Jayson (Contractor) Holter, Satellite Ground System Division
# Bunde,Brett (Contractor), Danny (Contractor) Howard, Science Division
# Danielson,Patrick (Contractor), Danny (Contractor) Howard, Science Division
# Butzer,Tony (Contractor), Cory (Contractor) Van Batavia, Satellite Ground System Division
# Dahal,Devendra (Contractor), Danny (Contractor) Howard, Science Division
# Wylie,Bruce K, Kristi Sayler, Integrated Science & Applications Branch
# Rover,Jennifer, Peter Doucette, Integrated Science & Applications Branch
# Zhou,Qiang (Contractor), Ramesh (Contractor) Singh, Science Division
# Rigge,Matthew B, Kristi Sayler, Integrated Science & Applications Branch
# Boyte,Stephen, Kristi Sayler, Integrated Science & Applications Branch
# Smith,Kelcy (Contractor) L, Ryan (Contractor) Reker, Science Division
# Anthony,Michelle (Contractor) L, Calli (Contractor) Jenkerson, Science Division
# Ballu,Anudeep (Contractor),,
# Mainali,Pukar (Contractor),,
# Sun,Minxuan,,
# Mcelhone,Maxwell T,,
# Young,Claudia (Contractor),,
# Holen,Cheryl (Contractor) L,,
# Pastick,Neal (Contractor) J,,
# Postma,Kory (Contractor),,
# Bunde,Brett (Contractor),,
# Danielson,Patrick (Contractor),,
# Dahal,Devendra (Contractor),,
# Wylie,Bruce K,,
# Rover,Jennifer,,
# Zhou,Qiang (Contractor),,
# Rigge,Matthew B,,
# Boyte,Stephen,,
# Smith,Kelcy (Contractor) L,,
# Anthony,Michelle (Contractor) L,,
# Benedict,Trenton D,,
# Shrestha,Dinesh,,
# Schoen,Candi (Contractor),,
# Oimoen,Michael (Contractor) J,,

# %% [markdown]
# # Groupby division

# %%
students=df

# %%
by_division = students.groupby('division').count()

# %%
by_division
# Out:
#                                            lastname  firstname  boss
# division
#  Integrated Science & Applications Branch         4          4     4
#  Satellite Ground System Division                 2          2     2
#  Science Division                                 7          7     7

# %%
type(by_division)
# Out:
# pandas.core.frame.DataFrame

# %%
howard = students[students['boss'].str.contains('Howard')]
# Out:
# ---------------------------------------------------------------------------
# ValueError                                Traceback (most recent call last)
# <ipython-input-8-39f077dc3d60> in <module>
# ----> 1 howard = students[students['boss'].str.contains('Howard')]
#
# /opt/tljh/user/lib/python3.7/site-packages/pandas/core/frame.py in __getitem__(self, key)
#    2894
#    2895         # Do we have a (boolean) 1d indexer?
# -> 2896         if com.is_bool_indexer(key):
#    2897             return self._getitem_bool_array(key)
#    2898
#
# /opt/tljh/user/lib/python3.7/site-packages/pandas/core/common.py in is_bool_indexer(key)
#     132                 na_msg = "Cannot mask with non-boolean array containing NA / NaN values"
#     133                 if isna(key).any():
# --> 134                     raise ValueError(na_msg)
#     135                 return False
#     136             return True
#
# ValueError: Cannot mask with non-boolean array containing NA / NaN values

# %% [markdown]
# # Who works for Danny Howard - I knew a Steve Howard

# %%
howard

# %%
science_folks = students[students['division'].str.contains('Science')]

# %%
science_folks

# %%
len(science_folks)

# %%
by_division

# %% [markdown]
# # Plot the classes of students using boss

# %%
boss_by_division = by_division['boss']

# %%
boss_by_division

# %%
boss_by_division.plot.pie(autopct='%1.1f%%', shadow = True)

# %%
boss_by_division.plot.bar()

# %% [markdown]
# # Improve the colors

# %%
from itertools import islice
from itertools import cycle
my_colors =  list(islice(cycle(['b', 'r', 'g', 'y', 'k']),None,len(boss_by_division)))

# %%
boss_by_division.plot(title='boss by division', kind='bar', stacked=True, color=my_colors)

# %%
sayler = students[students['boss'].str.contains('Sayler')]

# %%
sayler

# %%
print(students['lastname'])

# %%
lastname = students['lastname']
lastname

# %%
lastname_no_indices = lastname.to_string(index=False)

# %%
print(lastname_no_indices)

# %%
type(lastname_no_indices)

# %%
for i in lastname_no_indices.split('\n'):
    #print(i)
    i = i.lower()
    i = i.strip()
    print(i)
